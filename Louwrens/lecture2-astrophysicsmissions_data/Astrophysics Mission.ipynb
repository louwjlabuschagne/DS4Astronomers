# %% [markdown]
# Some notes I took whilst having our session with Tom

# %% [markdown]
# # Tom Jones
#
# + Centred around scientific method
# + Purpose of scientific method is to get the Data
# + Tom foccuses on visualizations tools, like VR
# + Get the data right!!!
#     + Quality of data matters
#     + Understand the data
#
#
# # Multi Wavelength Astrophysics
# + Think of the different wavelengths as the different physics that are occuring
#
# + Radio Waves- cosmic rays - "signatron radiation" - comes from supernova explotions, the other type of radiation is thermal radiation
# + infrared - almost inverse to optical as
# + Optical - looking at debree
# + Ultraviolet - measure O and B stars - the most massive stars
# + x-ray - highefst energey - looking down into the pulser - black holes
# For example
# ![](http://www.spaceacademy.net.au/env/sol/solradp/crabview.jpg)
#
#
# ![](https://mwmw.gsfc.nasa.gov/mwpics/mwmw_8x10.jpg)
#
# ![](http://ecuip.lib.uchicago.edu/multiwavelength-astronomy/images/astrophysics/MWA-whirlpool-galaxy.jpg)
#
# # now different wavelenghts have iffernet DBs
# + Need error model - Signal to Noise ratio
#     + S/N ratio is a type of homginosation
# + homogenious data Virtual observatives
# + flux measures vs. wavelenght
#     + flux measured in $Wm^{-2}$
# + Interaporability - bringing together the different wavelenghts
#
#
# # Types of missions
# + Observatories
#     + Propsals
#     + multiple instruments
#     + different measurement
#     + different datasets from same observatory
#     + HST
# + Surveys
#     + ex. SDSS, IRAS, WMAP
#     + big, observe large area
#     + simpler
#     + do well with databases - all the data is the same
#     + 4pi sky - the whole sky
#
# # Sloan
# + Redshift due to size of galaxies
# + stars don't red shift as we experience the same
# + u - hot stars
# + u,g,r,i,z bands
# + magnitude - log(intesity)
# + u-band detector
# + data points come from bands
# + m(AB)- different ways of calibratign magnitude system
# + m(Vega)
# + check coverage as well for dataset
# + types of coord systems
#     + equitorial coordinate system
#         + Mapped using solar t
#         + right a
#         + vernal equinox - 0 hours right accestions
#         + declination
#     + galactic coordinate system
#         + relative to mikly way
#     + degrees??to  signagecimals??
# + equal area projection
# + Object orientated database
#
#
# # Types of searches
# + Radial
# + Rectangular
# + SQL
#
# ```
# WHERE ra > 110, ra <115
# dec > 20 and dec < 21
# z > 0.001
#
#
# ```
#
#
# # NED
# + different kind of database\
# + Sloan and Infared made for big tables - survey data
# + NED though...
#     + smaller
#     + a lot of data on single objects
#     + unstructured
#     + about one object
# + FITS dataformat
